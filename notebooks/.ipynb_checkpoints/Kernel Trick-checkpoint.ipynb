# %%
import pandas as pds
import sklearn as skl
import seaborn as sns

# %%
planetas = pds.read_csv("cumulative.csv")

# %%
planetas
# Out:
#       rowid     kepid kepoi_name koi_disposition  koi_fpflag_nt  \
# 0         1  10797460  K00752.01       CONFIRMED              0
# 1         2  10797460  K00752.02       CONFIRMED              0
# 2         3  10811496  K00753.01  FALSE POSITIVE              0
# 3         4  10848459  K00754.01  FALSE POSITIVE              0
# 4         5  10854555  K00755.01       CONFIRMED              0
# ...     ...       ...        ...             ...            ...
# 9556   9560  10031643  K07984.01  FALSE POSITIVE              0
# 9557   9561  10090151  K07985.01  FALSE POSITIVE              0
# 9558   9562  10128825  K07986.01       CANDIDATE              0
# 9559   9563  10147276  K07987.01  FALSE POSITIVE              0
# 9560   9564  10156110  K07989.01  FALSE POSITIVE              0
#
#       koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  koi_time0bk  \
# 0                 0              0              0    9.488036   170.538750
# ...

# %%
sns.pairplot()
